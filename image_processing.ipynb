# %%
import cv2
import numpy as np
import os
from google.colab import drive
drive.mount('/gdrive')
from google.colab.patches import cv2_imshow
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
os.chdir("/gdrive/My Drive/dataset")
os.listdir()
# Out:
# ['data', 'red_rose', 'white_rose']

# %%
redimages = os.listdir("red_rose")
whiteimages = os.listdir("white_rose")

# %%
image=cv2.imread("red_rose/"+redimages[0])
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=104x104 at 0x7F8D7DC62A90>

# %%
img_hsv=cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2_imshow(img_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=104x104 at 0x7F8D7DBE5828>

# %%
lower_red = np.array([0,50,50])
upper_red = np.array([10,255,255])
mask0 = cv2.inRange(img_hsv, lower_red, upper_red)
cv2_imshow(mask0)
# Out:
# <PIL.Image.Image image mode=L size=104x104 at 0x7F8D7DBE5F60>

# %%
lower_red = np.array([170,50,50])
upper_red = np.array([180,255,255])
mask1 = cv2.inRange(img_hsv, lower_red, upper_red)
cv2_imshow(mask1)
# Out:
# <PIL.Image.Image image mode=L size=104x104 at 0x7F8D7DC6F2B0>

# %%
mask = mask0+mask1
cv2_imshow(mask1)
# Out:
# <PIL.Image.Image image mode=L size=104x104 at 0x7F8D7DC62F28>

# %%
output_img = image.copy()
output_img[np.where(mask==0)] = 0
cv2_imshow(output_img)
# Out:
# <PIL.Image.Image image mode=RGB size=104x104 at 0x7F8D7DB7F748>

# %%
output_hsv = img_hsv.copy()
output_hsv[np.where(mask==0)] = 0
cv2_imshow(output_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=104x104 at 0x7F8D7DB860F0>
